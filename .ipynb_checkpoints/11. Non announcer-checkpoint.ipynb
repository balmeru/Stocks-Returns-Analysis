# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1984.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1984.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1984.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1984.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1985.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1985.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1985.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1985.csv

# %%
import pandas as pd
import numpy as np

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1986.csv"
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1986.csv"

returns_pivot = pd.read_csv(returns_csv_path, index_col=0)
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)

# Convert index to datetime with errors='coerce' to handle NaT values
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='coerce')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='coerce')

# Drop rows with NaT index from both DataFrames
returns_pivot = returns_pivot.dropna()
announcement_pivot = announcement_pivot.dropna()

# Combine indices and sort
combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()

# Reindex DataFrames
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)

# Check if columns match
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"


non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1986.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1986.csv

# %%
import pandas as pd
import numpy as np

# File paths
returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1986.csv"
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1986.csv"

# Read CSV files into DataFrames
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)

# Convert index to datetime
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')
# Combine indices and sort
combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()

# Reindex DataFrames
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)

# Check if columns match
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

# %%
# Identify rows where announcement_pivot contains unexpected values
incorrect_announcements = announcement_pivot[~announcement_pivot.isin([True, False])]

if not incorrect_announcements.empty:
    print("Rows with unexpected values in announcement_pivot:")
    print(incorrect_announcements)

# Optionally, print rows from returns_pivot that correspond to the problematic rows in announcement_pivot
for index in incorrect_announcements.index:
    if index in returns_pivot.index:
        print(f"Corresponding data in returns_pivot for index {index}:")
        print(returns_pivot.loc[index])
    else:
        print(f"No corresponding data in returns_pivot for index {index}")
# Out:
# Rows with unexpected values in announcement_pivot:
#            0223B 3614B 3ACDGE 3ACKH 3ACTRQ 3ADLN 3ADOT. 3AHTC 3AMMBQ 3ANDA  \
# 1985-12-30   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-01-06   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-01-13   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-01-20   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-01-27   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-02-03   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-02-10   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-02-17   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-02-24   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-03-03   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-03-10   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-03-17   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-03-24   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-03-31   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-04-07   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-04-14   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-04-21   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-04-28   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-05-05   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-05-12   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-05-19   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-05-26   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-06-02   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-06-09   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-06-16   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-06-23   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-06-30   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-07-07   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-07-14   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-07-21   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-07-28   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-08-04   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-08-11   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-08-18   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-08-25   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-09-01   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-09-08   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-09-15   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-09-22   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-09-29   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-10-06   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-10-13   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-10-20   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-10-27   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-11-03   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-11-10   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-11-17   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-11-24   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-12-01   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-12-08   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-12-15   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# 1986-12-22   NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
# NaT          NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN    NaN   NaN
#
#             ... ZAPS. ZENL ZGCO ZIGO ZIM.1 ZION  ZMX ZRBA  ZRN  ZRO
# 1985-12-30  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-01-06  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-01-13  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-01-20  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-01-27  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-02-03  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-02-10  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-02-17  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-02-24  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-03-03  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-03-10  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-03-17  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-03-24  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-03-31  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-04-07  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-04-14  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-04-21  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-04-28  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-05-05  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-05-12  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-05-19  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-05-26  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-06-02  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-06-09  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-06-16  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-06-23  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-06-30  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-07-07  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-07-14  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-07-21  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-07-28  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-08-04  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-08-11  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-08-18  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-08-25  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-09-01  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-09-08  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-09-15  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-09-22  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-09-29  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-10-06  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-10-13  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-10-20  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-10-27  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-11-03  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-11-10  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-11-17  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-11-24  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-12-01  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-12-08  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-12-15  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1986-12-22  ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# NaT         ...   NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
#
# [53 rows x 2284 columns]
# Corresponding data in returns_pivot for index 1985-12-30 00:00:00:
# 0223B       -0.621118
# 3614B     6.332453826
# 3ACDGE            0.0
# 3ACKH        1.420455
# 3ACTRQ       1.102941
#              ...
# ZION        -2.479339
# ZMX         -0.990099
# ZRBA         4.878049
# ZRN          3.061224
# ZRO         -2.673797
# Name: 1985-12-30 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-01-06 00:00:00:
# 0223B            -2.5
# 3614B     2.729528536
# 3ACDGE       2.777778
# 3ACKH       -7.282913
# 3ACTRQ      -0.363636
#              ...
# ZION        -1.129944
# ZMX               2.0
# ZRBA        11.627907
# ZRN          1.650165
# ZRO         -6.043956
# Name: 1986-01-06 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-01-13 00:00:00:
# 0223B         3.846154
# 3614B     -0.966183575
# 3ACDGE       -4.043243
# 3ACKH             -0.0
# 3ACTRQ       -5.109489
#               ...
# ZION               4.0
# ZMX           8.823529
# ZRBA              -0.0
# ZRN           2.597403
# ZRO          -2.923977
# Name: 1986-01-13 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-01-20 00:00:00:
# 0223B        -0.617284
# 3614B     -3.170731707
# 3ACDGE        1.397026
# 3ACKH         -0.60423
# 3ACTRQ       -7.692308
#               ...
# ZION          3.846154
# ZMX           1.801802
# ZRBA             -6.25
# ZRN           6.329114
# ZRO           1.204819
# Name: 1986-01-20 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-01-27 00:00:00:
# 0223B      2.484472
# 3614B     -1.11E-14
# 3ACDGE    -5.555556
# 3ACKH      9.422492
# 3ACTRQ     3.333333
#             ...
# ZION       8.994709
# ZMX       -7.964602
# ZRBA       2.222222
# ZRN       -2.083333
# ZRO        2.380952
# Name: 1986-01-27 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-02-03 00:00:00:
# 0223B         2.424242
# 3614B     -3.778337531
# 3ACDGE             0.0
# 3ACKH          3.78965
# 3ACTRQ        8.870968
#               ...
# ZION         -1.456311
# ZMX           2.884615
# ZRBA         -4.347826
# ZRN           3.343465
# ZRO           5.232558
# Name: 1986-02-03 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-02-10 00:00:00:
# 0223B       -1.183432
# 3614B     7.853403141
# 3ACDGE      -5.882353
# 3ACKH        2.425876
# 3ACTRQ       2.962963
#              ...
# ZION        -2.463054
# ZMX          1.682243
# ZRBA        22.727273
# ZRN               0.0
# ZRO         -0.159068
# Name: 1986-02-10 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-02-17 00:00:00:
# 0223B         0.392873
# 3614B     -2.912621359
# 3ACDGE           -6.25
# 3ACKH         5.263158
# 3ACTRQ        3.956835
#               ...
# ZION          1.010101
# ZMX           2.777778
# ZRBA          3.703704
# ZRN           1.176471
# ZRO           9.444444
# Name: 1986-02-17 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-02-24 00:00:00:
# 0223B    -0.606061
# 3614B         9.25
# 3ACDGE   -3.333333
# 3ACKH          3.0
# 3ACTRQ    1.038062
#             ...
# ZION           4.0
# ZMX       6.306306
# ZRBA      7.142857
# ZRN       0.872093
# ZRO      -0.507614
# Name: 1986-02-24 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-03-03 00:00:00:
# 0223B         3.658537
# 3614B     -0.686498856
# 3ACDGE             0.0
# 3ACKH        15.776699
# 3ACTRQ       -9.589041
#               ...
# ZION         -1.442308
# ZMX           2.542373
# ZRBA         23.333333
# ZRN           4.610951
# ZRO           1.530612
# Name: 1986-03-03 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-03-10 00:00:00:
# 0223B       -4.705882
# 3614B     7.603686636
# 3ACDGE      10.344828
# 3ACKH        0.628931
# 3ACTRQ           -0.0
#              ...
# ZION             -0.0
# ZMX         -4.132231
# ZRBA        -2.702703
# ZRN         -2.870246
# ZRO          8.040201
# Name: 1986-03-10 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-03-17 00:00:00:
# 0223B        1.234568
# 3614B     2.980727738
# 3ACDGE         21.875
# 3ACKH       -0.208333
# 3ACTRQ      -6.060606
#              ...
# ZION         1.463415
# ZMX         -1.724138
# ZRBA              0.0
# ZRN         -3.428571
# ZRO         -2.325581
# Name: 1986-03-17 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-03-24 00:00:00:
# 0223B       -0.609756
# 3614B     6.302521008
# 3ACDGE           -6.4
# 3ACKH        1.878914
# 3ACTRQ       -4.83871
#              ...
# ZION          4.02537
# ZMX         -0.877193
# ZRBA        -4.166667
# ZRN          3.254438
# ZRO         -4.761905
# Name: 1986-03-24 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-03-31 00:00:00:
# 0223B       -1.840491
# 3614B     -7.90513834
# 3ACDGE           -0.0
# 3ACKH       -8.196721
# 3ACTRQ       7.627119
#              ...
# ZION              0.0
# ZMX         -2.654867
# ZRBA         1.449275
# ZRN          -7.73639
# ZRO               2.5
# Name: 1986-03-31 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-04-07 00:00:00:
# 0223B             0.0
# 3614B     5.150214592
# 3ACDGE      -4.120096
# 3ACKH       10.267857
# 3ACTRQ       2.362205
#              ...
# ZION         0.465116
# ZMX          0.458182
# ZRBA             6.56
# ZRN          1.242236
# ZRO         -0.609756
# Name: 1986-04-07 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-04-14 00:00:00:
# 0223B           3.125
# 3614B     0.408163265
# 3ACDGE      -9.988571
# 3ACKH        2.631579
# 3ACTRQ      -5.384615
#              ...
# ZION         0.925926
# ZMX          0.904945
# ZRBA         2.702703
# ZRN          5.828221
# ZRO          2.453988
# Name: 1986-04-14 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-04-21 00:00:00:
# 0223B      1.212121
# 3614B             s
# 3ACDGE    -1.599797
# 3ACKH     -1.380671
# 3ACTRQ     3.252033
#             ...
# ZION       1.834862
# ZMX       -2.245659
# ZRBA      26.315789
# ZRN         1.15942
# ZRO        -2.39521
# Name: 1986-04-21 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-04-28 00:00:00:
# 0223B        -3.592814
# 3614B     -6.072874494
# 3ACDGE       -4.825806
# 3ACKH              0.0
# 3ACTRQ       -2.362205
#               ...
# ZION          -0.45045
# ZMX          -1.834862
# ZRBA         16.666667
# ZRN          -5.444126
# ZRO               -0.0
# Name: 1986-04-28 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-05-05 00:00:00:
# 0223B         3.10559
# 3614B     1.724137931
# 3ACDGE     -25.433839
# 3ACKH        2.172619
# 3ACTRQ      -3.225806
#              ...
# ZION         5.882353
# ZMX         -4.672897
# ZRBA        -7.142857
# ZRN           0.30303
# ZRO         -4.907975
# Name: 1986-05-05 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-05-12 00:00:00:
# 0223B        -0.216868
# 3614B     -4.872881356
# 3ACDGE        6.836364
# 3ACKH        -1.771654
# 3ACTRQ            -2.5
#               ...
# ZION          4.700855
# ZMX           2.941176
# ZRBA         -9.615385
# ZRN           0.302115
# ZRO           0.369231
# Name: 1986-05-12 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-05-19 00:00:00:
# 0223B        1.840491
# 3614B     10.24498886
# 3ACDGE      -6.398911
# 3ACKH        1.402806
# 3ACTRQ       6.837607
#              ...
# ZION        -3.265306
# ZMX          1.904762
# ZRBA         4.255319
# ZRN           0.60241
# ZRO         -0.645161
# Name: 1986-05-19 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-05-26 00:00:00:
# 0223B             0.0
# 3614B     0.202020202
# 3ACDGE      -4.545455
# 3ACKH        3.754941
# 3ACTRQ            7.2
#              ...
# ZION        -0.421941
# ZMX         -0.934579
# ZRBA        -4.081633
# ZRN         -2.994012
# ZRO         -2.597403
# Name: 1986-05-26 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-06-02 00:00:00:
# 0223B        -1.807229
# 3614B     -3.427419355
# 3ACDGE            -0.0
# 3ACKH         4.380952
# 3ACTRQ       -0.746269
#               ...
# ZION         -0.847458
# ZMX            7.35187
# ZRBA          6.382979
# ZRN          -2.469136
# ZRO          -3.333333
# Name: 1986-06-02 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-06-09 00:00:00:
# 0223B         1.226994
# 3614B     -0.208768267
# 3ACDGE             2.4
# 3ACKH         1.459854
# 3ACTRQ       -1.503759
#               ...
# ZION         -0.854701
# ZMX          -0.884956
# ZRBA              22.0
# ZRN          -2.659045
# ZRO            1.37931
# Name: 1986-06-09 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-06-16 00:00:00:
# 0223B        -0.606061
# 3614B     -2.510460251
# 3ACDGE        2.306548
# 3ACKH        -2.338129
# 3ACTRQ       -2.290076
#               ...
# ZION         -1.293103
# ZMX          -0.892857
# ZRBA          1.639344
# ZRN          -2.622951
# ZRO          -1.360544
# Name: 1986-06-16 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-06-23 00:00:00:
# 0223B        0.609756
# 3614B     1.287553648
# 3ACDGE            0.0
# 3ACKH       -5.524862
# 3ACTRQ         1.5625
#              ...
# ZION         2.345753
# ZMX         -2.702703
# ZRBA        -3.225806
# ZRN          1.683502
# ZRO         -3.448276
# Name: 1986-06-23 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-06-30 00:00:00:
# 0223B             0.0
# 3614B     1.906779661
# 3ACDGE            0.0
# 3ACKH       -1.559454
# 3ACTRQ      -3.076923
#              ...
# ZION         0.429185
# ZMX         -2.777778
# ZRBA         3.333333
# ZRN               0.0
# ZRO          3.571429
# Name: 1986-06-30 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-07-07 00:00:00:
# 0223B        4.242424
# 3614B     -1.03950104
# 3ACDGE       2.290909
# 3ACKH       -9.306931
# 3ACTRQ      -6.349206
#              ...
# ZION        -0.854701
# ZMX         -3.809524
# ZRBA         3.225806
# ZRN         -4.635762
# ZRO         -8.965517
# Name: 1986-07-07 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-07-14 00:00:00:
# 0223B         6.976744
# 3614B     -7.773109244
# 3ACDGE       -2.239602
# 3ACKH        -2.183406
# 3ACTRQ      -10.169492
#               ...
# ZION              -0.0
# ZMX          -1.980198
# ZRBA            -9.375
# ZRN          -4.166667
# ZRO          -0.757576
# Name: 1986-07-14 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-07-21 00:00:00:
# 0223B        2.717391
# 3614B     2.290812712
# 3ACDGE      -9.090909
# 3ACKH        5.803571
# 3ACTRQ       5.660377
#              ...
# ZION        -7.758621
# ZMX         -6.561616
# ZRBA         5.172414
# ZRN          -3.26087
# ZRO          6.870229
# Name: 1986-07-21 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-07-28 00:00:00:
# 0223B        -2.645503
# 3614B     -8.558558559
# 3ACDGE          -12.48
# 3ACKH        -8.438819
# 3ACTRQ       -2.678571
#               ...
# ZION          3.738318
# ZMX          -1.625876
# ZRBA         -2.459016
# ZRN           4.868914
# ZRO         -13.571429
# Name: 1986-07-28 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-08-04 00:00:00:
# 0223B        1.630435
# 3614B     4.433497537
# 3ACDGE      19.972578
# 3ACKH        3.669543
# 3ACTRQ      -1.834862
#              ...
# ZION        -4.504505
# ZMX         -1.098901
# ZRBA        -7.563025
# ZRN          5.714286
# ZRO         -1.652893
# Name: 1986-08-04 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-08-11 00:00:00:
# 0223B            -0.0
# 3614B     3.301886792
# 3ACDGE            0.0
# 3ACKH        5.369128
# 3ACTRQ       5.607477
#              ...
# ZION         1.415094
# ZMX         -1.111111
# ZRBA         3.636364
# ZRN          1.013514
# ZRO          4.723595
# Name: 1986-08-11 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-08-18 00:00:00:
# 0223B       -1.262032
# 3614B     1.598173516
# 3ACDGE     -16.647619
# 3ACKH       -1.910828
# 3ACTRQ       0.884956
#              ...
# ZION              0.0
# ZMX         -0.797131
# ZRBA        -5.263158
# ZRN          2.006689
# ZRO          5.645161
# Name: 1986-08-18 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-08-25 00:00:00:
# 0223B       -1.648352
# 3614B     1.348314607
# 3ACDGE        5.71298
# 3ACKH        1.948052
# 3ACTRQ       1.754386
#              ...
# ZION        -0.697674
# ZMX         -2.861583
# ZRBA        -0.925926
# ZRN         -0.327869
# ZRO          0.763359
# Name: 1986-08-25 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-09-01 00:00:00:
# 0223B       -0.558659
# 3614B     -2.88248337
# 3ACDGE      -5.404237
# 3ACKH        1.698514
# 3ACTRQ           -0.0
#              ...
# ZION        -2.107728
# ZMX          1.769412
# ZRBA        -4.672897
# ZRN         -3.947368
# ZRO         -0.757576
# Name: 1986-09-01 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-09-08 00:00:00:
# 0223B        -9.550562
# 3614B     -6.849315068
# 3ACDGE      -25.731261
# 3ACKH       -11.482255
# 3ACTRQ       -2.586207
#               ...
# ZION         -5.263158
# ZMX          -2.894664
# ZRBA         -5.882353
# ZRN          -1.878091
# ZRO          -6.870229
# Name: 1986-09-08 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-09-15 00:00:00:
# 0223B     1.863354
# 3614B            0
# 3ACDGE    7.692308
# 3ACKH    -2.830189
# 3ACTRQ   -1.327434
#             ...
# ZION     -4.545455
# ZMX      -4.761905
# ZRBA         -6.25
# ZRN       0.352113
# ZRO      -8.196721
# Name: 1986-09-15 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-09-22 00:00:00:
# 0223B             -0.0
# 3614B     -0.980392157
# 3ACDGE       -7.142857
# 3ACKH         0.970874
# 3ACTRQ        1.345291
#               ...
# ZION          1.553561
# ZMX               3.75
# ZRBA         -3.333333
# ZRN           0.350877
# ZRO           3.571429
# Name: 1986-09-22 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-09-29 00:00:00:
# 0223B        1.219512
# 3614B     -2.97029703
# 3ACDGE       3.876923
# 3ACKH        3.846154
# 3ACTRQ            0.0
#              ...
# ZION         0.262467
# ZMX          1.204819
# ZRBA        -3.448276
# ZRN          -0.34965
# ZRO         -7.758621
# Name: 1986-09-29 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-10-06 00:00:00:
# 0223B         -0.60241
# 3614B     -1.530612245
# 3ACDGE       -7.405213
# 3ACKH        -0.462963
# 3ACTRQ        5.309735
#               ...
# ZION          -0.26178
# ZMX          29.761905
# ZRBA         -7.142857
# ZRN           5.964912
# ZRO                0.0
# Name: 1986-10-06 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-10-13 00:00:00:
# 0223B         1.212121
# 3614B     -0.518134715
# 3ACDGE             0.0
# 3ACKH         1.627907
# 3ACTRQ        0.840336
#               ...
# ZION         -2.887139
# ZMX         -16.513761
# ZRBA               0.0
# ZRN           0.331126
# ZRO           9.345794
# Name: 1986-10-13 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-10-20 00:00:00:
# 0223B        3.592814
# 3614B     3.385416667
# 3ACDGE            0.0
# 3ACKH        3.661327
# 3ACTRQ       1.666667
#              ...
# ZION        -0.540541
# ZMX          3.296703
# ZRBA              0.0
# ZRN               0.0
# ZRO               0.0
# Name: 1986-10-20 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-10-27 00:00:00:
# 0223B        4.046243
# 3614B     5.067704791
# 3ACDGE      -7.997441
# 3ACKH        0.883002
# 3ACTRQ      -1.639344
#              ...
# ZION         1.086957
# ZMX          -1.06383
# ZRBA         7.692308
# ZRN          1.650165
# ZRO          3.418803
# Name: 1986-10-27 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-11-03 00:00:00:
# 0223B           0.0
# 3614B     -1.11E-14
# 3ACDGE   -34.770515
# 3ACKH      6.730778
# 3ACTRQ     1.666667
#             ...
# ZION        1.88172
# ZMX       -2.150538
# ZRBA      10.714286
# ZRN            -0.0
# ZRO       -4.482645
# Name: 1986-11-03 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-11-10 00:00:00:
# 0223B         2.222222
# 3614B     -1.941747573
# 3ACDGE        6.609808
# 3ACKH         1.440329
# 3ACTRQ       -0.819672
#               ...
# ZION         -0.791557
# ZMX           1.098901
# ZRBA              -0.0
# ZRN          -0.324675
# ZRO           0.869565
# Name: 1986-11-10 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-11-17 00:00:00:
# 0223B     -0.179621
# 3614B      2.22E-14
# 3ACDGE         -6.2
# 3ACKH      1.825558
# 3ACTRQ     0.826446
#             ...
# ZION      -4.255319
# ZMX        6.521739
# ZRBA     -16.129032
# ZRN         2.28013
# ZRO       -3.448276
# Name: 1986-11-17 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-11-24 00:00:00:
# 0223B       0.552486
# 3614B     2.97029703
# 3ACDGE     13.326226
# 3ACKH       1.195219
# 3ACTRQ      1.639344
#              ...
# ZION       -0.555556
# ZMX         5.102041
# ZRBA             0.0
# ZRN         4.140127
# ZRO         5.357143
# Name: 1986-11-24 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-12-01 00:00:00:
# 0223B       -1.098901
# 3614B     4.807692308
# 3ACDGE       5.832549
# 3ACKH        7.874016
# 3ACTRQ       4.032258
#              ...
# ZION        -6.703911
# ZMX          8.510211
# ZRBA         5.769231
# ZRN          2.752294
# ZRO          2.542373
# Name: 1986-12-01 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-12-08 00:00:00:
# 0223B         0.555556
# 3614B     -1.376146789
# 3ACDGE       11.111111
# 3ACKH        -7.664234
# 3ACTRQ       -0.775194
#               ...
# ZION         -1.197605
# ZMX          -3.603604
# ZRBA         -1.818182
# ZRN          -1.613945
# ZRO           2.479339
# Name: 1986-12-08 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-12-15 00:00:00:
# 0223B            -0.0
# 3614B     1.395348837
# 3ACDGE            0.0
# 3ACKH       -0.790514
# 3ACTRQ        -1.5625
#              ...
# ZION        -0.606061
# ZMX          1.869159
# ZRBA        -5.555556
# ZRN         -2.743902
# ZRO         -2.419355
# Name: 1986-12-15 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index 1986-12-22 00:00:00:
# 0223B        -2.209945
# 3614B     -2.064220183
# 3ACDGE             0.0
# 3ACKH        -0.398406
# 3ACTRQ        1.587302
#               ...
# ZION         -0.951219
# ZMX          -1.834862
# ZRBA         -9.803922
# ZRN          -1.567398
# ZRO          -2.479339
# Name: 1986-12-22 00:00:00, Length: 2284, dtype: object
# Corresponding data in returns_pivot for index NaT:
# 0223B     NaN
# 3614B     NaN
# 3ACDGE    NaN
# 3ACKH     NaN
# 3ACTRQ    NaN
#          ...
# ZION      NaN
# ZMX       NaN
# ZRBA      NaN
# ZRN       NaN
# ZRO       NaN
# Name: NaT, Length: 2284, dtype: object

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1987.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1987.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1987.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1987.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1988.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1988.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1988.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1988.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1989.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1989.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1989.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1989.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1990.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1990.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1990.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1990.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1991.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1991.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1991.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1991.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1992.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1992.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1992.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1992.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1993.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1993.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1993.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1993.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1994.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1994.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1994.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1994.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1995.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1995.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1995.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1995.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1996.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1996.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1996.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1996.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1997.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1997.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1997.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1997.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1998.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1998.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1998.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1998.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_1999.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_1999.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_1999.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_1999.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2000.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2000.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2000.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2000.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2001.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2001.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2001.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2001.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2002.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2002.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2002.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2002.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2003.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2003.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2003.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2003.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2004.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2004.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2004.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2004.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2005.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2005.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2005.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2005.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2006.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2006.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2006.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2006.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2007.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2007.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2007.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2007.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2008.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2008.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2008.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2008.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2009.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2009.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2009.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2009.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2010.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2010.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2010.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2010.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2011.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2011.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2011.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2011.csv

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, date

returns_csv_path = "C:/Users/balmeru/Downloads/filtered_weekly_returns_2012.csv"  
announcement_csv_path = "C:/Users/balmeru/Downloads/True_False_2012.csv"  
returns_pivot = pd.read_csv(returns_csv_path, index_col=0)  
announcement_pivot = pd.read_csv(announcement_csv_path, index_col=0)  
returns_pivot.index = pd.to_datetime(returns_pivot.index, errors='raise')
announcement_pivot.index = pd.to_datetime(announcement_pivot.index, errors='raise')

combined_index = returns_pivot.index.union(announcement_pivot.index).unique().sort_values()
returns_pivot = returns_pivot.reindex(combined_index)
announcement_pivot = announcement_pivot.reindex(combined_index)
assert returns_pivot.columns.equals(announcement_pivot.columns), "Columns do not match"

non_announcer_frame = returns_pivot.copy()
non_announcer_frame[announcement_pivot != False] = np.nan  # Set to NaN where not explicitly `False`
non_announcer_frame['Average Return'] = non_announcer_frame.mean(axis=1, skipna=True)  # Compute the average excluding NaNs

output_csv_path = "C:/Users/balmeru/Downloads/non_announcer_frame_2012.csv"  # Change to your desired output path
non_announcer_frame.to_csv(output_csv_path)
print(f"The Non-Announcer Frame has been created and saved to {output_csv_path}")
# Out:
# The Non-Announcer Frame has been created and saved to C:/Users/balmeru/Downloads/non_announcer_frame_2012.csv
